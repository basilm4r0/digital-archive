# %%
import requests

# %%
import requests
import json
import pprint

class OmekaSGateway(object):
    def __init__(self, install_location, key_identity, key_credential):
        self.install_location = install_location
        self.key_identity = key_identity
        self.key_credential = key_credential

    def get_final_uri(self, endpoint):
        return endpoint.format(
            self.install_location,
            self.key_identity,
            self.key_credential
        )
        
    def create_page(self, data):
        endpoint = "{}/api/site_pages?key_identity={}&key_credential={}"
        item_payload = {
        }
        final_uri = endpoint.format(self.install_location, self.key_identity, self.key_credential)
        r = requests.post(self.get_final_uri(endpoint), json=data)
        return r.json()

    def get_page_by_slug(self, slug):
        return next((x for x in self.list_site_pages() if x['o:slug'] == slug), None)

    def get_item_by_title(self, title):
        return next((x for x in self.list_items() if x['o:title'] == title), None)

    def update_page(self, id_, data):
        endpoint = "{}/api/site_pages/{}?key_identity={}&key_credential={}"
        requests.put(
            endpoint.format(self.install_location, id_, self.key_identity, self.key_credential),
            json=data
        )

    def list_site_pages(self):
        final_uri = self.get_final_uri("{}/api/site_pages?key_identity={}&key_credential={}")
        r = requests.get(final_uri)
        return r.json()

    def list_items(self):
        final_uri = "{}/api/items?key_identity={}&key_credential={}".format(
            self.install_location,
            self.key_identity,
            self.key_credential
        )
        r = requests.get(final_uri)
        return r.json()

    def create_item_with_media(self, item_payload, path, mime_type):
        endpoint = "{}/api/items?key_identity={}&key_credential={}"
        postdata = {}

        final_uri = endpoint.format(
            self.install_location,
            self.key_identity,
            self.key_credential
        )

        r = requests.post(final_uri, data={'data': json.dumps(item_payload)}, files=[
            ('file[0]', (path, open(path, 'rb'), mime_type))
        ])

        if r.ok:
            return r.json()
            print(r.status_code)
        else:
            raise Exception(r.json()['errors']['error'])

# %%
api = OmekaSGateway('http://localhost:8080',
                   '5UxoiInyatZiEIpUOmB9YOPXkrENK3IE',
                   'dhz4REYtv7E8qabZ1CMxz4KmiAZFCHCi')

# %%
api.list_items()
# Out:
# [{'@context': 'http://localhost:8080/api-context',
#   '@id': 'http://localhost:8080/api/items/3',
#   '@type': ['o:Item', 'foaf:Person'],
#   'o:id': 3,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://localhost:8080/api/users/1', 'o:id': 1},
#   'o:resource_class': {'@id': 'http://localhost:8080/api/resource_classes/94',
#    'o:id': 94},
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Some Writer',
#   'thumbnail_display_urls': {'large': None, 'medium': None, 'square': None},
#   'o:created': {'@value': '2021-06-07T16:34:10+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2021-06-07T16:34:10+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:media': [],
#   'o:item_set': [],
#   'o:site': [{'@id': 'http://localhost:8080/api/sites/1', 'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Some Writer'}]},
#  {'@context': 'http://localhost:8080/api-context',
#   '@id': 'http://localhost:8080/api/items/6',
#   '@type': 'o:Item',
#   'o:id': 6,
#   'o:is_public': False,
#   'o:owner': {'@id': 'http://localhost:8080/api/users/1', 'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Test',
#   'thumbnail_display_urls': {'large': 'http://localhost:8080/files/large/d65d77ad03902b0fd4fcd2a018ed255ef7c2d87c.jpg',
#    'medium': 'http://localhost:8080/files/medium/d65d77ad03902b0fd4fcd2a018ed255ef7c2d87c.jpg',
#    'square': 'http://localhost:8080/files/square/d65d77ad03902b0fd4fcd2a018ed255ef7c2d87c.jpg'},
#   'o:created': {'@value': '2021-06-08T16:32:32+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2021-06-08T17:13:35+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:media': [{'@id': 'http://localhost:8080/api/media/7', 'o:id': 7}],
#   'o:item_set': [{'@id': 'http://localhost:8080/api/item_sets/5', 'o:id': 5}],
#   'o:site': [{'@id': 'http://localhost:8080/api/sites/1', 'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Test'}]},
#  {'@context': 'http://localhost:8080/api-context',
#   '@id': 'http://localhost:8080/api/items/8',
#   '@type': 'o:Item',
#   'o:id': 8,
#   'o:is_public': True,
#   'o:owner': {'@id': 'http://localhost:8080/api/users/1', 'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'Test upload',
#   'thumbnail_display_urls': {'large': '/application/asset/thumbnails/default.png?v=3.0.2',
#    'medium': '/application/asset/thumbnails/default.png?v=3.0.2',
#    'square': '/application/asset/thumbnails/default.png?v=3.0.2'},
#   'o:created': {'@value': '2021-06-08T17:13:07+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2021-06-09T08:28:39+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:media': [{'@id': 'http://localhost:8080/api/media/9', 'o:id': 9}],
#   'o:item_set': [{'@id': 'http://localhost:8080/api/item_sets/5', 'o:id': 5}],
#   'o:site': [{'@id': 'http://localhost:8080/api/sites/1', 'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'Test upload'}],
#   'dcterms:creator': [{'type': 'resource',
#     'property_id': 2,
#     'property_label': 'Creator',
#     'is_public': True,
#     '@id': 'http://localhost:8080/api/items/3',
#     'value_resource_id': 3,
#     'value_resource_name': 'items',
#     'url': None,
#     'display_title': 'Some Writer'}]},
#  {'@context': 'http://localhost:8080/api-context',
#   '@id': 'http://localhost:8080/api/items/10',
#   '@type': 'o:Item',
#   'o:id': 10,
#   'o:is_public': False,
#   'o:owner': {'@id': 'http://localhost:8080/api/users/1', 'o:id': 1},
#   'o:resource_class': None,
#   'o:resource_template': None,
#   'o:thumbnail': None,
#   'o:title': 'My Upload',
#   'thumbnail_display_urls': {'large': '/application/asset/thumbnails/default.png?v=3.0.2',
#    'medium': '/application/asset/thumbnails/default.png?v=3.0.2',
#    'square': '/application/asset/thumbnails/default.png?v=3.0.2'},
#   'o:created': {'@value': '2021-06-09T08:34:54+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:modified': {'@value': '2021-06-09T08:37:00+00:00',
#    '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#   'o:media': [{'@id': 'http://localhost:8080/api/media/11', 'o:id': 11}],
#   'o:item_set': [{'@id': 'http://localhost:8080/api/item_sets/5', 'o:id': 5}],
#   'o:site': [{'@id': 'http://localhost:8080/api/sites/1', 'o:id': 1}],
#   'dcterms:title': [{'type': 'literal',
#     'property_id': 1,
#     'property_label': 'Title',
#     'is_public': True,
#     '@value': 'My Upload'}],
#   'dcterms:creator': [{'type': 'resource',
#     'property_id': 2,
#     'property_label': 'Creator',
#     'is_public': True,
#     '@id': 'http://localhost:8080/api/items/3',
#     'value_resource_id': 3,
#     'value_resource_name': 'items',
#     'url': None,
#     'display_title': 'Some Writer'}]}]
